# %% [markdown]
# # TripletNet3: Mixed-kernel Conv1D triplet encoder
#
# This notebook trains the model with **5-fold anchor-group cross-validation** and then runs a thesis-oriented post-training analysis suite. The quantitative analysis prioritizes out-of-fold validation predictions; the latent-space and nearest-neighbour sections are used for interpretability and qualitative diagnosis.

# %%
from __future__ import annotations

from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

from cv_training import (
    FoldTrainingConfig,
    TRIPLET_COLUMNS,
    make_artist_disjoint_kfold_splits,
    run_one_fold_margin,
    summarize_cv_results,
)
from dataset import filter_triplets, process_artists
from model import MODEL_REGISTRY
from utils import set_seed

# %%
SEED = 3407
set_seed(SEED)

MODEL_NAME = "TripletNet3"
MODEL_CLASS = MODEL_REGISTRY[MODEL_NAME]

BASE_DIR = Path("../data/video_embeddings")
TRIPLETS_CSV = Path("../data/triplets/triplets_ids_music_spot.csv")
OUTPUT_DIR = Path("checkpoints") / MODEL_NAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR = Path("figures") / MODEL_NAME.lower().replace("tripletnet", "model")
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

def save_figure(fig, filename: str) -> Path:
    path = FIGURES_DIR / filename
    fig.tight_layout()
    fig.savefig(path, dpi=300, bbox_inches="tight")
    print(f"Saved figure: {path}")
    return path

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 128
NUM_EPOCHS = 30
N_FOLDS = 5
NUM_WORKERS = 0
OPTIMIZER = "adamw"
LEARNING_RATE = 2e-4
WEIGHT_DECAY = 1e-5
EARLY_STOPPING_PATIENCE = 8
MARGINS = [0.1, 0.3, 0.5, 0.7, 0.9]

print(f"Using device: {DEVICE}")
print(f"Model: {MODEL_NAME}")
print(f"5-fold CV with {N_FOLDS} artist-disjoint folds")
print(f"fixed CSV negatives | margin grid={MARGINS} | optimizer={OPTIMIZER} | batch_size={BATCH_SIZE} | lr={LEARNING_RATE:.1e} | weight_decay={WEIGHT_DECAY:.1e}")
# Out:
# Using device: cuda
# Model: TripletNet3
# 5-fold CV with 5 artist-disjoint folds
# fixed CSV negatives | margin grid=[0.1, 0.3, 0.5, 0.7, 0.9] | optimizer=adamw | batch_size=128 | lr=2.0e-04 | weight_decay=1.0e-05

# %%
artist_averages = process_artists(BASE_DIR)
if not artist_averages:
    raise RuntimeError(f"No artist embeddings found under {BASE_DIR!s}. Check BASE_DIR.")

sample_embedding = next(iter(artist_averages.values()))
if sample_embedding.ndim != 2:
    raise ValueError(f"Expected artist embeddings shaped (seq_len, d_model), got {tuple(sample_embedding.shape)}")

SEQ_LEN = int(sample_embedding.shape[0])
D_MODEL = int(sample_embedding.shape[1])
MODEL_KWARGS = {"d_model": D_MODEL, "seq_len": SEQ_LEN}

raw_triplet_df = pd.read_csv(TRIPLETS_CSV)
filtered_triplet_df = filter_triplets(raw_triplet_df, artist_averages)
if filtered_triplet_df.empty:
    raise RuntimeError("No usable triplets after filtering. Check triplet CSV IDs and embedding folders.")

folds = make_artist_disjoint_kfold_splits(filtered_triplet_df, n_splits=N_FOLDS, seed=SEED)
fold_stats_df = pd.DataFrame([stats for _, _, _, stats in folds])

print(f"Artists with embeddings: {len(artist_averages)}")
print(f"Filtered triplets: {len(filtered_triplet_df)}")
print(f"Embedding shape: seq_len={SEQ_LEN}, d_model={D_MODEL}")
display(fold_stats_df)
# Out:
# Artists with embeddings: 3892
# Filtered triplets: 27350
# Embedding shape: seq_len=30, d_model=768
#    fold               strategy  train_rows  val_rows  \
# 0     1  artist_disjoint_kfold       14117       228
# 1     2  artist_disjoint_kfold       13790       235
# 2     3  artist_disjoint_kfold       14337       218
# 3     4  artist_disjoint_kfold       14060       216
# 4     5  artist_disjoint_kfold       13837       235
#
#    dropped_cross_partition_rows  kept_row_ratio  train_artists  val_artists  \
# 0                         13005        0.524497           2404          375
# 1                         13325        0.512797           2405          378
# 2                         12795        0.532176           2405          365
# 3                         13074        0.521974           2406          366
# 4                         13278        0.514516           2406          384
#
#    train_artist_partition_size  val_artist_partition_size  anchor_overlap  \
# 0                         2405                        602           False
# 1                         2405                        602           False
# 2                         2406                        601           False
# 3                         2406                        601           False
# 4                         2406                        601           False
#
#    artist_overlap
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
training_config = FoldTrainingConfig(
    model_name=MODEL_NAME,
    model_class=MODEL_CLASS,
    model_kwargs=MODEL_KWARGS,
    output_dir=OUTPUT_DIR,
    device=DEVICE,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    num_epochs=NUM_EPOCHS,
    optimizer_name=OPTIMIZER,
    learning_rate=LEARNING_RATE,
    weight_decay=WEIGHT_DECAY,
    early_stopping_patience=EARLY_STOPPING_PATIENCE,
    distance_fn="cosine",
    grad_clip=1.0,
)


def make_model():
    return MODEL_CLASS(**MODEL_KWARGS).to(DEVICE)

# %%
results = []

for margin in MARGINS:
    for fold_id, train_df, val_df, fold_stats in folds:
        print("=" * 100)
        print(
            f"Training {MODEL_NAME}: fixed CSV negatives, "
            f"margin={margin:.2f}, fold={fold_id}/{N_FOLDS} | "
            f"train_rows={fold_stats['train_rows']} | val_rows={fold_stats['val_rows']}"
        )
        results.append(
            run_one_fold_margin(
                fold_id,
                train_df,
                val_df,
                margin,
                artist_averages,
                training_config,
            )
        )

fold_summary_df, margin_summary_df = summarize_cv_results(results, OUTPUT_DIR, MODEL_NAME)

display(fold_summary_df)
display(margin_summary_df)
# Out:
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.10, fold=1/5 | train_rows=14117 | val_rows=228
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=001/30 | train_loss=0.04862 | train_acc=86.36% | val_loss=0.03063 | val_mrr=0.2967 | val_acc=93.86% | val_margin_acc=84.21% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=002/30 | train_loss=0.02821 | train_acc=92.82% | val_loss=0.03511 | val_mrr=0.2946 | val_acc=89.91% | val_margin_acc=83.77% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=003/30 | train_loss=0.02226 | train_acc=94.52% | val_loss=0.03978 | val_mrr=0.2746 | val_acc=92.11% | val_margin_acc=84.65% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=004/30 | train_loss=0.01876 | train_acc=95.47% | val_loss=0.03696 | val_mrr=0.2639 | val_acc=91.23% | val_margin_acc=84.65% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=005/30 | train_loss=0.01651 | train_acc=96.08% | val_loss=0.04156 | val_mrr=0.2657 | val_acc=89.04% | val_margin_acc=83.77% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=006/30 | train_loss=0.01349 | train_acc=96.84% | val_loss=0.03555 | val_mrr=0.2507 | val_acc=92.11% | val_margin_acc=85.96% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=007/30 | train_loss=0.01224 | train_acc=97.15% | val_loss=0.03407 | val_mrr=0.2662 | val_acc=90.35% | val_margin_acc=85.09% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=008/30 | train_loss=0.01060 | train_acc=97.60% | val_loss=0.03583 | val_mrr=0.2683 | val_acc=91.23% | val_margin_acc=85.96% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.10 | epoch=009/30 | train_loss=0.01022 | train_acc=97.54% | val_loss=0.03643 | val_mrr=0.2684 | val_acc=90.79% | val_margin_acc=85.53% | lr=9.80e-05
# Early stopping at epoch 9: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.10, fold=2/5 | train_rows=13790 | val_rows=235
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=001/30 | train_loss=0.04992 | train_acc=85.79% | val_loss=0.04401 | val_mrr=0.2386 | val_acc=89.36% | val_margin_acc=81.70% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=002/30 | train_loss=0.02730 | train_acc=92.82% | val_loss=0.03812 | val_mrr=0.2423 | val_acc=90.21% | val_margin_acc=84.68% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=003/30 | train_loss=0.02121 | train_acc=94.78% | val_loss=0.03573 | val_mrr=0.2437 | val_acc=91.49% | val_margin_acc=86.38% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=004/30 | train_loss=0.01889 | train_acc=95.41% | val_loss=0.03474 | val_mrr=0.2250 | val_acc=91.49% | val_margin_acc=89.36% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=005/30 | train_loss=0.01568 | train_acc=96.30% | val_loss=0.03631 | val_mrr=0.2604 | val_acc=92.77% | val_margin_acc=85.96% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=006/30 | train_loss=0.01454 | train_acc=96.47% | val_loss=0.03321 | val_mrr=0.2409 | val_acc=91.91% | val_margin_acc=86.38% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=007/30 | train_loss=0.01264 | train_acc=97.00% | val_loss=0.03604 | val_mrr=0.2435 | val_acc=91.06% | val_margin_acc=85.53% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=008/30 | train_loss=0.01151 | train_acc=97.22% | val_loss=0.04145 | val_mrr=0.2256 | val_acc=91.49% | val_margin_acc=86.81% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=009/30 | train_loss=0.01075 | train_acc=97.55% | val_loss=0.03990 | val_mrr=0.2400 | val_acc=91.49% | val_margin_acc=83.83% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=010/30 | train_loss=0.00926 | train_acc=97.80% | val_loss=0.03529 | val_mrr=0.2151 | val_acc=91.91% | val_margin_acc=86.81% | lr=1.40e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=011/30 | train_loss=0.00760 | train_acc=98.32% | val_loss=0.04023 | val_mrr=0.2085 | val_acc=90.64% | val_margin_acc=87.66% | lr=1.40e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=012/30 | train_loss=0.00637 | train_acc=98.61% | val_loss=0.03963 | val_mrr=0.2296 | val_acc=90.21% | val_margin_acc=85.96% | lr=1.40e-04
# fold=2 | fixed CSV negatives | margin=0.10 | epoch=013/30 | train_loss=0.00602 | train_acc=98.63% | val_loss=0.03840 | val_mrr=0.2165 | val_acc=91.06% | val_margin_acc=88.09% | lr=1.40e-04
# Early stopping at epoch 13: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.10, fold=3/5 | train_rows=14337 | val_rows=218
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=001/30 | train_loss=0.04853 | train_acc=85.63% | val_loss=0.04642 | val_mrr=0.2193 | val_acc=92.20% | val_margin_acc=82.11% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=002/30 | train_loss=0.02823 | train_acc=92.67% | val_loss=0.04020 | val_mrr=0.2078 | val_acc=91.28% | val_margin_acc=82.57% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=003/30 | train_loss=0.02203 | train_acc=94.60% | val_loss=0.04660 | val_mrr=0.2435 | val_acc=88.99% | val_margin_acc=84.40% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=004/30 | train_loss=0.01939 | train_acc=95.22% | val_loss=0.04345 | val_mrr=0.2447 | val_acc=90.83% | val_margin_acc=83.03% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=005/30 | train_loss=0.01584 | train_acc=96.10% | val_loss=0.05238 | val_mrr=0.2463 | val_acc=89.45% | val_margin_acc=83.49% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=006/30 | train_loss=0.01438 | train_acc=96.63% | val_loss=0.04910 | val_mrr=0.2727 | val_acc=91.74% | val_margin_acc=83.49% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=007/30 | train_loss=0.01140 | train_acc=97.37% | val_loss=0.04833 | val_mrr=0.2804 | val_acc=89.91% | val_margin_acc=86.24% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=008/30 | train_loss=0.01083 | train_acc=97.52% | val_loss=0.04871 | val_mrr=0.2763 | val_acc=91.74% | val_margin_acc=85.78% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=009/30 | train_loss=0.00958 | train_acc=97.78% | val_loss=0.04713 | val_mrr=0.2649 | val_acc=91.74% | val_margin_acc=86.24% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=010/30 | train_loss=0.00984 | train_acc=97.64% | val_loss=0.05375 | val_mrr=0.2760 | val_acc=89.45% | val_margin_acc=86.70% | lr=9.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=011/30 | train_loss=0.00778 | train_acc=98.17% | val_loss=0.04929 | val_mrr=0.2701 | val_acc=91.74% | val_margin_acc=85.32% | lr=9.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=012/30 | train_loss=0.00672 | train_acc=98.63% | val_loss=0.04698 | val_mrr=0.2859 | val_acc=92.20% | val_margin_acc=85.78% | lr=9.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=013/30 | train_loss=0.00660 | train_acc=98.64% | val_loss=0.05608 | val_mrr=0.2618 | val_acc=92.20% | val_margin_acc=84.86% | lr=9.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=014/30 | train_loss=0.00616 | train_acc=98.75% | val_loss=0.05251 | val_mrr=0.2734 | val_acc=90.83% | val_margin_acc=85.78% | lr=6.86e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=015/30 | train_loss=0.00518 | train_acc=98.86% | val_loss=0.05940 | val_mrr=0.2562 | val_acc=88.53% | val_margin_acc=81.65% | lr=6.86e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=016/30 | train_loss=0.00482 | train_acc=99.02% | val_loss=0.05305 | val_mrr=0.2475 | val_acc=90.83% | val_margin_acc=84.40% | lr=6.86e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=017/30 | train_loss=0.00430 | train_acc=99.05% | val_loss=0.06179 | val_mrr=0.2534 | val_acc=89.45% | val_margin_acc=85.32% | lr=6.86e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=018/30 | train_loss=0.00439 | train_acc=99.09% | val_loss=0.05859 | val_mrr=0.2525 | val_acc=89.91% | val_margin_acc=83.49% | lr=4.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=019/30 | train_loss=0.00369 | train_acc=99.24% | val_loss=0.05976 | val_mrr=0.2550 | val_acc=89.91% | val_margin_acc=83.03% | lr=4.80e-05
# fold=3 | fixed CSV negatives | margin=0.10 | epoch=020/30 | train_loss=0.00366 | train_acc=99.29% | val_loss=0.05854 | val_mrr=0.2544 | val_acc=90.37% | val_margin_acc=82.57% | lr=4.80e-05
# Early stopping at epoch 20: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.10, fold=4/5 | train_rows=14060 | val_rows=216
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=001/30 | train_loss=0.04865 | train_acc=86.03% | val_loss=0.03313 | val_mrr=0.2443 | val_acc=93.06% | val_margin_acc=89.35% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=002/30 | train_loss=0.02674 | train_acc=92.87% | val_loss=0.03579 | val_mrr=0.2613 | val_acc=92.59% | val_margin_acc=90.28% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=003/30 | train_loss=0.02109 | train_acc=94.63% | val_loss=0.03305 | val_mrr=0.2647 | val_acc=93.06% | val_margin_acc=87.50% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=004/30 | train_loss=0.01861 | train_acc=95.27% | val_loss=0.03821 | val_mrr=0.2821 | val_acc=92.59% | val_margin_acc=86.11% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=005/30 | train_loss=0.01631 | train_acc=95.91% | val_loss=0.03745 | val_mrr=0.2882 | val_acc=92.13% | val_margin_acc=88.43% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=006/30 | train_loss=0.01367 | train_acc=96.69% | val_loss=0.03685 | val_mrr=0.2787 | val_acc=92.13% | val_margin_acc=88.43% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=007/30 | train_loss=0.01305 | train_acc=97.01% | val_loss=0.03487 | val_mrr=0.2830 | val_acc=93.06% | val_margin_acc=89.81% | lr=1.40e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=008/30 | train_loss=0.01028 | train_acc=97.52% | val_loss=0.04019 | val_mrr=0.2647 | val_acc=93.06% | val_margin_acc=89.35% | lr=1.40e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=009/30 | train_loss=0.00935 | train_acc=97.81% | val_loss=0.03712 | val_mrr=0.2808 | val_acc=93.52% | val_margin_acc=90.28% | lr=1.40e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=010/30 | train_loss=0.00839 | train_acc=97.98% | val_loss=0.03958 | val_mrr=0.2647 | val_acc=94.44% | val_margin_acc=87.04% | lr=1.40e-04
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=011/30 | train_loss=0.00789 | train_acc=98.05% | val_loss=0.04029 | val_mrr=0.2849 | val_acc=93.98% | val_margin_acc=90.28% | lr=9.80e-05
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=012/30 | train_loss=0.00689 | train_acc=98.39% | val_loss=0.04292 | val_mrr=0.2684 | val_acc=91.20% | val_margin_acc=87.50% | lr=9.80e-05
# fold=4 | fixed CSV negatives | margin=0.10 | epoch=013/30 | train_loss=0.00599 | train_acc=98.76% | val_loss=0.03622 | val_mrr=0.2666 | val_acc=93.98% | val_margin_acc=89.81% | lr=9.80e-05
# Early stopping at epoch 13: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.10, fold=5/5 | train_rows=13837 | val_rows=235
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=001/30 | train_loss=0.05119 | train_acc=84.68% | val_loss=0.03518 | val_mrr=0.2292 | val_acc=89.36% | val_margin_acc=84.26% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=002/30 | train_loss=0.02690 | train_acc=93.29% | val_loss=0.03791 | val_mrr=0.2353 | val_acc=88.09% | val_margin_acc=83.83% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=003/30 | train_loss=0.02234 | train_acc=94.21% | val_loss=0.04206 | val_mrr=0.2386 | val_acc=89.36% | val_margin_acc=82.98% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=004/30 | train_loss=0.01863 | train_acc=95.06% | val_loss=0.04165 | val_mrr=0.2420 | val_acc=90.21% | val_margin_acc=83.83% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=005/30 | train_loss=0.01698 | train_acc=95.88% | val_loss=0.04371 | val_mrr=0.2434 | val_acc=89.36% | val_margin_acc=84.68% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=006/30 | train_loss=0.01326 | train_acc=96.78% | val_loss=0.04507 | val_mrr=0.2369 | val_acc=90.64% | val_margin_acc=85.96% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=007/30 | train_loss=0.01185 | train_acc=97.09% | val_loss=0.04297 | val_mrr=0.2177 | val_acc=89.36% | val_margin_acc=85.96% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=008/30 | train_loss=0.01116 | train_acc=97.31% | val_loss=0.04920 | val_mrr=0.2361 | val_acc=89.79% | val_margin_acc=84.26% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=009/30 | train_loss=0.01086 | train_acc=97.51% | val_loss=0.04083 | val_mrr=0.2070 | val_acc=90.64% | val_margin_acc=84.68% | lr=9.80e-05
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=010/30 | train_loss=0.00834 | train_acc=98.09% | val_loss=0.04361 | val_mrr=0.2224 | val_acc=89.36% | val_margin_acc=86.81% | lr=9.80e-05
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=011/30 | train_loss=0.00770 | train_acc=98.34% | val_loss=0.04365 | val_mrr=0.2166 | val_acc=89.79% | val_margin_acc=86.38% | lr=9.80e-05
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=012/30 | train_loss=0.00747 | train_acc=98.37% | val_loss=0.04646 | val_mrr=0.2133 | val_acc=89.36% | val_margin_acc=85.96% | lr=9.80e-05
# fold=5 | fixed CSV negatives | margin=0.10 | epoch=013/30 | train_loss=0.00669 | train_acc=98.48% | val_loss=0.04837 | val_mrr=0.2201 | val_acc=89.36% | val_margin_acc=83.83% | lr=6.86e-05
# Early stopping at epoch 13: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.30, fold=1/5 | train_rows=14117 | val_rows=228
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=001/30 | train_loss=0.13536 | train_acc=87.24% | val_loss=0.11828 | val_mrr=0.2499 | val_acc=88.16% | val_margin_acc=73.68% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=002/30 | train_loss=0.07705 | train_acc=93.62% | val_loss=0.09943 | val_mrr=0.2671 | val_acc=90.35% | val_margin_acc=75.44% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=003/30 | train_loss=0.06357 | train_acc=94.98% | val_loss=0.10186 | val_mrr=0.2764 | val_acc=91.23% | val_margin_acc=75.44% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=004/30 | train_loss=0.05532 | train_acc=95.91% | val_loss=0.10365 | val_mrr=0.2687 | val_acc=91.67% | val_margin_acc=74.56% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=005/30 | train_loss=0.04773 | train_acc=96.49% | val_loss=0.10353 | val_mrr=0.2692 | val_acc=88.60% | val_margin_acc=75.00% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=006/30 | train_loss=0.04315 | train_acc=96.90% | val_loss=0.09896 | val_mrr=0.2510 | val_acc=89.04% | val_margin_acc=76.32% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=007/30 | train_loss=0.03909 | train_acc=97.29% | val_loss=0.09029 | val_mrr=0.2695 | val_acc=92.54% | val_margin_acc=76.75% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=008/30 | train_loss=0.03776 | train_acc=97.46% | val_loss=0.10484 | val_mrr=0.2615 | val_acc=89.91% | val_margin_acc=77.63% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=009/30 | train_loss=0.03404 | train_acc=97.78% | val_loss=0.10392 | val_mrr=0.2676 | val_acc=90.79% | val_margin_acc=75.00% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=010/30 | train_loss=0.03116 | train_acc=98.04% | val_loss=0.10469 | val_mrr=0.2653 | val_acc=91.23% | val_margin_acc=78.51% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.30 | epoch=011/30 | train_loss=0.02991 | train_acc=98.14% | val_loss=0.10166 | val_mrr=0.2577 | val_acc=89.04% | val_margin_acc=77.19% | lr=1.40e-04
# Early stopping at epoch 11: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.30, fold=2/5 | train_rows=13790 | val_rows=235
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=001/30 | train_loss=0.13138 | train_acc=87.96% | val_loss=0.10778 | val_mrr=0.2425 | val_acc=90.64% | val_margin_acc=75.32% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=002/30 | train_loss=0.07575 | train_acc=93.76% | val_loss=0.09913 | val_mrr=0.2234 | val_acc=90.64% | val_margin_acc=79.57% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=003/30 | train_loss=0.06204 | train_acc=94.96% | val_loss=0.10104 | val_mrr=0.2402 | val_acc=90.21% | val_margin_acc=79.15% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=004/30 | train_loss=0.05352 | train_acc=95.87% | val_loss=0.09640 | val_mrr=0.2361 | val_acc=90.64% | val_margin_acc=78.30% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=005/30 | train_loss=0.04758 | train_acc=96.40% | val_loss=0.10921 | val_mrr=0.2242 | val_acc=89.36% | val_margin_acc=76.60% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=006/30 | train_loss=0.04272 | train_acc=97.16% | val_loss=0.10265 | val_mrr=0.2202 | val_acc=88.09% | val_margin_acc=77.45% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=007/30 | train_loss=0.03966 | train_acc=97.41% | val_loss=0.10960 | val_mrr=0.2158 | val_acc=89.36% | val_margin_acc=77.02% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=008/30 | train_loss=0.03471 | train_acc=97.65% | val_loss=0.10428 | val_mrr=0.2412 | val_acc=90.64% | val_margin_acc=79.57% | lr=1.40e-04
# fold=2 | fixed CSV negatives | margin=0.30 | epoch=009/30 | train_loss=0.03111 | train_acc=98.09% | val_loss=0.10925 | val_mrr=0.2200 | val_acc=88.51% | val_margin_acc=79.57% | lr=1.40e-04
# Early stopping at epoch 9: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.30, fold=3/5 | train_rows=14337 | val_rows=218
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=001/30 | train_loss=0.13631 | train_acc=86.72% | val_loss=0.11829 | val_mrr=0.2255 | val_acc=92.20% | val_margin_acc=76.15% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=002/30 | train_loss=0.07680 | train_acc=93.73% | val_loss=0.13059 | val_mrr=0.2449 | val_acc=90.37% | val_margin_acc=72.02% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=003/30 | train_loss=0.06319 | train_acc=94.99% | val_loss=0.12918 | val_mrr=0.2469 | val_acc=87.16% | val_margin_acc=74.77% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=004/30 | train_loss=0.05320 | train_acc=96.05% | val_loss=0.11478 | val_mrr=0.2836 | val_acc=88.99% | val_margin_acc=75.23% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=005/30 | train_loss=0.04928 | train_acc=96.27% | val_loss=0.12298 | val_mrr=0.2426 | val_acc=92.20% | val_margin_acc=75.69% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=006/30 | train_loss=0.04370 | train_acc=96.95% | val_loss=0.11758 | val_mrr=0.2557 | val_acc=91.74% | val_margin_acc=75.23% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=007/30 | train_loss=0.04013 | train_acc=97.31% | val_loss=0.11613 | val_mrr=0.2494 | val_acc=90.83% | val_margin_acc=77.06% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=008/30 | train_loss=0.03709 | train_acc=97.42% | val_loss=0.10775 | val_mrr=0.2663 | val_acc=91.28% | val_margin_acc=77.06% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=009/30 | train_loss=0.03378 | train_acc=97.92% | val_loss=0.12321 | val_mrr=0.2542 | val_acc=88.99% | val_margin_acc=76.15% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=010/30 | train_loss=0.03206 | train_acc=98.10% | val_loss=0.12220 | val_mrr=0.2425 | val_acc=89.91% | val_margin_acc=76.15% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=011/30 | train_loss=0.02954 | train_acc=98.22% | val_loss=0.10301 | val_mrr=0.2375 | val_acc=92.20% | val_margin_acc=76.61% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.30 | epoch=012/30 | train_loss=0.02911 | train_acc=98.40% | val_loss=0.11484 | val_mrr=0.2477 | val_acc=92.20% | val_margin_acc=77.52% | lr=2.00e-04
# Early stopping at epoch 12: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.30, fold=4/5 | train_rows=14060 | val_rows=216
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=001/30 | train_loss=0.12998 | train_acc=87.54% | val_loss=0.10730 | val_mrr=0.2593 | val_acc=91.20% | val_margin_acc=78.24% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=002/30 | train_loss=0.07447 | train_acc=93.71% | val_loss=0.09530 | val_mrr=0.2617 | val_acc=91.20% | val_margin_acc=81.94% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=003/30 | train_loss=0.06051 | train_acc=95.29% | val_loss=0.09068 | val_mrr=0.2651 | val_acc=93.52% | val_margin_acc=81.94% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=004/30 | train_loss=0.05366 | train_acc=95.67% | val_loss=0.09413 | val_mrr=0.2578 | val_acc=92.13% | val_margin_acc=83.80% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=005/30 | train_loss=0.04670 | train_acc=96.61% | val_loss=0.08971 | val_mrr=0.2519 | val_acc=90.74% | val_margin_acc=85.19% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=006/30 | train_loss=0.04273 | train_acc=96.71% | val_loss=0.08748 | val_mrr=0.2528 | val_acc=92.59% | val_margin_acc=82.41% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=007/30 | train_loss=0.03897 | train_acc=97.21% | val_loss=0.08987 | val_mrr=0.2502 | val_acc=91.67% | val_margin_acc=81.48% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=008/30 | train_loss=0.03584 | train_acc=97.30% | val_loss=0.08672 | val_mrr=0.2503 | val_acc=92.59% | val_margin_acc=83.33% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=009/30 | train_loss=0.03308 | train_acc=97.79% | val_loss=0.08490 | val_mrr=0.2581 | val_acc=91.20% | val_margin_acc=81.94% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=010/30 | train_loss=0.03146 | train_acc=98.01% | val_loss=0.09029 | val_mrr=0.2625 | val_acc=91.20% | val_margin_acc=82.87% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.30 | epoch=011/30 | train_loss=0.02999 | train_acc=98.06% | val_loss=0.08574 | val_mrr=0.2450 | val_acc=91.67% | val_margin_acc=82.87% | lr=2.00e-04
# Early stopping at epoch 11: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.30, fold=5/5 | train_rows=13837 | val_rows=235
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=001/30 | train_loss=0.13396 | train_acc=87.24% | val_loss=0.10538 | val_mrr=0.2495 | val_acc=88.51% | val_margin_acc=75.32% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=002/30 | train_loss=0.07314 | train_acc=94.23% | val_loss=0.10855 | val_mrr=0.2466 | val_acc=88.09% | val_margin_acc=78.30% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=003/30 | train_loss=0.06126 | train_acc=95.34% | val_loss=0.10016 | val_mrr=0.2368 | val_acc=91.06% | val_margin_acc=73.19% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=004/30 | train_loss=0.05313 | train_acc=96.17% | val_loss=0.10514 | val_mrr=0.2722 | val_acc=89.36% | val_margin_acc=77.02% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=005/30 | train_loss=0.04782 | train_acc=96.40% | val_loss=0.09982 | val_mrr=0.2488 | val_acc=89.79% | val_margin_acc=75.74% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=006/30 | train_loss=0.04321 | train_acc=96.98% | val_loss=0.10583 | val_mrr=0.2623 | val_acc=88.94% | val_margin_acc=75.74% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=007/30 | train_loss=0.04020 | train_acc=97.11% | val_loss=0.10221 | val_mrr=0.2620 | val_acc=89.36% | val_margin_acc=76.17% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=008/30 | train_loss=0.03735 | train_acc=97.35% | val_loss=0.10538 | val_mrr=0.2281 | val_acc=89.36% | val_margin_acc=76.60% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=009/30 | train_loss=0.03419 | train_acc=97.56% | val_loss=0.09961 | val_mrr=0.2334 | val_acc=88.94% | val_margin_acc=73.19% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=010/30 | train_loss=0.03241 | train_acc=98.02% | val_loss=0.11586 | val_mrr=0.2571 | val_acc=90.21% | val_margin_acc=75.32% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=011/30 | train_loss=0.03014 | train_acc=97.93% | val_loss=0.12286 | val_mrr=0.2471 | val_acc=88.94% | val_margin_acc=71.49% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.30 | epoch=012/30 | train_loss=0.02836 | train_acc=98.35% | val_loss=0.11596 | val_mrr=0.2407 | val_acc=90.21% | val_margin_acc=72.77% | lr=2.00e-04
# Early stopping at epoch 12: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.50, fold=1/5 | train_rows=14117 | val_rows=228
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=001/30 | train_loss=0.24428 | train_acc=86.24% | val_loss=0.23977 | val_mrr=0.2135 | val_acc=85.53% | val_margin_acc=57.02% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=002/30 | train_loss=0.15206 | train_acc=93.13% | val_loss=0.20432 | val_mrr=0.1957 | val_acc=89.47% | val_margin_acc=60.09% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=003/30 | train_loss=0.12763 | train_acc=94.65% | val_loss=0.18828 | val_mrr=0.2307 | val_acc=91.23% | val_margin_acc=64.91% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=004/30 | train_loss=0.11164 | train_acc=95.35% | val_loss=0.17733 | val_mrr=0.2264 | val_acc=91.23% | val_margin_acc=61.84% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=005/30 | train_loss=0.10373 | train_acc=95.93% | val_loss=0.17779 | val_mrr=0.2358 | val_acc=91.23% | val_margin_acc=64.04% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=006/30 | train_loss=0.09678 | train_acc=96.27% | val_loss=0.18704 | val_mrr=0.2388 | val_acc=90.79% | val_margin_acc=67.11% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=007/30 | train_loss=0.08895 | train_acc=96.54% | val_loss=0.18302 | val_mrr=0.2503 | val_acc=89.91% | val_margin_acc=66.23% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=008/30 | train_loss=0.08279 | train_acc=96.98% | val_loss=0.18459 | val_mrr=0.2388 | val_acc=89.91% | val_margin_acc=66.67% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=009/30 | train_loss=0.07421 | train_acc=97.41% | val_loss=0.17790 | val_mrr=0.2608 | val_acc=89.91% | val_margin_acc=67.11% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=010/30 | train_loss=0.07033 | train_acc=97.68% | val_loss=0.19486 | val_mrr=0.2273 | val_acc=89.04% | val_margin_acc=64.47% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=011/30 | train_loss=0.06877 | train_acc=97.68% | val_loss=0.18202 | val_mrr=0.2414 | val_acc=91.23% | val_margin_acc=68.86% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=012/30 | train_loss=0.06567 | train_acc=97.91% | val_loss=0.18576 | val_mrr=0.2467 | val_acc=90.79% | val_margin_acc=66.23% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=013/30 | train_loss=0.06191 | train_acc=97.97% | val_loss=0.18498 | val_mrr=0.2573 | val_acc=89.91% | val_margin_acc=66.67% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=014/30 | train_loss=0.05868 | train_acc=98.09% | val_loss=0.18787 | val_mrr=0.2543 | val_acc=91.23% | val_margin_acc=65.35% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=015/30 | train_loss=0.05755 | train_acc=98.21% | val_loss=0.19425 | val_mrr=0.2468 | val_acc=89.91% | val_margin_acc=65.35% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=016/30 | train_loss=0.05578 | train_acc=98.24% | val_loss=0.17861 | val_mrr=0.2659 | val_acc=91.67% | val_margin_acc=66.23% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=017/30 | train_loss=0.05222 | train_acc=98.43% | val_loss=0.18888 | val_mrr=0.2505 | val_acc=92.11% | val_margin_acc=62.28% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=018/30 | train_loss=0.05126 | train_acc=98.51% | val_loss=0.19709 | val_mrr=0.2571 | val_acc=91.67% | val_margin_acc=64.04% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=019/30 | train_loss=0.04999 | train_acc=98.46% | val_loss=0.19266 | val_mrr=0.2441 | val_acc=90.35% | val_margin_acc=64.47% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=020/30 | train_loss=0.04935 | train_acc=98.53% | val_loss=0.19950 | val_mrr=0.2465 | val_acc=88.60% | val_margin_acc=62.28% | lr=4.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=021/30 | train_loss=0.04683 | train_acc=98.73% | val_loss=0.18267 | val_mrr=0.2448 | val_acc=91.67% | val_margin_acc=62.72% | lr=4.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=022/30 | train_loss=0.04499 | train_acc=98.75% | val_loss=0.18780 | val_mrr=0.2443 | val_acc=90.79% | val_margin_acc=63.60% | lr=4.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=023/30 | train_loss=0.04517 | train_acc=98.81% | val_loss=0.19084 | val_mrr=0.2356 | val_acc=90.79% | val_margin_acc=63.16% | lr=4.80e-05
# fold=1 | fixed CSV negatives | margin=0.50 | epoch=024/30 | train_loss=0.04436 | train_acc=98.72% | val_loss=0.18090 | val_mrr=0.2600 | val_acc=93.42% | val_margin_acc=62.72% | lr=3.36e-05
# Early stopping at epoch 24: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.50, fold=2/5 | train_rows=13790 | val_rows=235
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=001/30 | train_loss=0.24993 | train_acc=85.98% | val_loss=0.19594 | val_mrr=0.2021 | val_acc=90.21% | val_margin_acc=64.26% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=002/30 | train_loss=0.15138 | train_acc=93.18% | val_loss=0.18007 | val_mrr=0.2572 | val_acc=90.64% | val_margin_acc=67.66% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=003/30 | train_loss=0.12578 | train_acc=94.65% | val_loss=0.17380 | val_mrr=0.2446 | val_acc=89.79% | val_margin_acc=68.51% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=004/30 | train_loss=0.11110 | train_acc=95.27% | val_loss=0.16461 | val_mrr=0.2367 | val_acc=90.64% | val_margin_acc=67.66% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=005/30 | train_loss=0.10231 | train_acc=95.92% | val_loss=0.16037 | val_mrr=0.2342 | val_acc=91.91% | val_margin_acc=69.79% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=006/30 | train_loss=0.09248 | train_acc=96.39% | val_loss=0.17007 | val_mrr=0.2245 | val_acc=92.34% | val_margin_acc=69.79% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=007/30 | train_loss=0.08675 | train_acc=96.69% | val_loss=0.16380 | val_mrr=0.2159 | val_acc=91.06% | val_margin_acc=72.34% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=008/30 | train_loss=0.08069 | train_acc=96.85% | val_loss=0.16896 | val_mrr=0.2099 | val_acc=91.49% | val_margin_acc=70.21% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=009/30 | train_loss=0.07693 | train_acc=97.19% | val_loss=0.15550 | val_mrr=0.2159 | val_acc=90.64% | val_margin_acc=70.64% | lr=2.00e-04
# fold=2 | fixed CSV negatives | margin=0.50 | epoch=010/30 | train_loss=0.07256 | train_acc=97.53% | val_loss=0.16445 | val_mrr=0.2135 | val_acc=90.21% | val_margin_acc=72.34% | lr=2.00e-04
# Early stopping at epoch 10: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.50, fold=3/5 | train_rows=14337 | val_rows=218
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=001/30 | train_loss=0.24991 | train_acc=86.02% | val_loss=0.19914 | val_mrr=0.2290 | val_acc=91.74% | val_margin_acc=66.97% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=002/30 | train_loss=0.14818 | train_acc=93.51% | val_loss=0.22048 | val_mrr=0.2233 | val_acc=89.45% | val_margin_acc=65.14% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=003/30 | train_loss=0.12606 | train_acc=94.55% | val_loss=0.19641 | val_mrr=0.2282 | val_acc=91.74% | val_margin_acc=66.51% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=004/30 | train_loss=0.11060 | train_acc=95.68% | val_loss=0.19828 | val_mrr=0.2161 | val_acc=89.91% | val_margin_acc=65.14% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=005/30 | train_loss=0.10095 | train_acc=96.06% | val_loss=0.20122 | val_mrr=0.2079 | val_acc=88.53% | val_margin_acc=64.68% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=006/30 | train_loss=0.09295 | train_acc=96.46% | val_loss=0.18740 | val_mrr=0.2435 | val_acc=89.91% | val_margin_acc=67.89% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=007/30 | train_loss=0.08531 | train_acc=97.15% | val_loss=0.20323 | val_mrr=0.2242 | val_acc=88.07% | val_margin_acc=64.22% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=008/30 | train_loss=0.08054 | train_acc=97.22% | val_loss=0.20332 | val_mrr=0.2287 | val_acc=89.45% | val_margin_acc=64.68% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=009/30 | train_loss=0.07713 | train_acc=97.48% | val_loss=0.20326 | val_mrr=0.2097 | val_acc=89.91% | val_margin_acc=63.76% | lr=2.00e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=010/30 | train_loss=0.07290 | train_acc=97.57% | val_loss=0.20750 | val_mrr=0.2151 | val_acc=89.45% | val_margin_acc=67.89% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=011/30 | train_loss=0.06596 | train_acc=97.90% | val_loss=0.19253 | val_mrr=0.2167 | val_acc=89.45% | val_margin_acc=65.14% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=012/30 | train_loss=0.06351 | train_acc=98.02% | val_loss=0.20155 | val_mrr=0.2169 | val_acc=89.45% | val_margin_acc=65.60% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=013/30 | train_loss=0.06092 | train_acc=98.15% | val_loss=0.20564 | val_mrr=0.1917 | val_acc=89.91% | val_margin_acc=65.14% | lr=1.40e-04
# fold=3 | fixed CSV negatives | margin=0.50 | epoch=014/30 | train_loss=0.05824 | train_acc=98.20% | val_loss=0.20528 | val_mrr=0.2031 | val_acc=88.07% | val_margin_acc=66.06% | lr=9.80e-05
# Early stopping at epoch 14: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.50, fold=4/5 | train_rows=14060 | val_rows=216
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=001/30 | train_loss=0.24802 | train_acc=86.37% | val_loss=0.17174 | val_mrr=0.2575 | val_acc=92.13% | val_margin_acc=69.91% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=002/30 | train_loss=0.14438 | train_acc=93.58% | val_loss=0.15429 | val_mrr=0.2679 | val_acc=92.59% | val_margin_acc=75.93% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=003/30 | train_loss=0.12399 | train_acc=94.67% | val_loss=0.15214 | val_mrr=0.2648 | val_acc=93.98% | val_margin_acc=74.07% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=004/30 | train_loss=0.10849 | train_acc=95.70% | val_loss=0.14940 | val_mrr=0.2545 | val_acc=91.67% | val_margin_acc=75.00% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=005/30 | train_loss=0.09863 | train_acc=96.19% | val_loss=0.15208 | val_mrr=0.2696 | val_acc=92.13% | val_margin_acc=74.54% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=006/30 | train_loss=0.09169 | train_acc=96.58% | val_loss=0.15694 | val_mrr=0.2644 | val_acc=91.20% | val_margin_acc=74.54% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=007/30 | train_loss=0.08497 | train_acc=96.79% | val_loss=0.14878 | val_mrr=0.2577 | val_acc=92.13% | val_margin_acc=73.15% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=008/30 | train_loss=0.08160 | train_acc=97.16% | val_loss=0.14457 | val_mrr=0.2645 | val_acc=92.13% | val_margin_acc=75.46% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=009/30 | train_loss=0.07595 | train_acc=97.30% | val_loss=0.16363 | val_mrr=0.2624 | val_acc=91.67% | val_margin_acc=75.46% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=010/30 | train_loss=0.07372 | train_acc=97.47% | val_loss=0.15054 | val_mrr=0.2382 | val_acc=91.67% | val_margin_acc=74.07% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=011/30 | train_loss=0.07119 | train_acc=97.48% | val_loss=0.14141 | val_mrr=0.2522 | val_acc=91.67% | val_margin_acc=74.54% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=012/30 | train_loss=0.06712 | train_acc=97.71% | val_loss=0.15047 | val_mrr=0.2330 | val_acc=91.67% | val_margin_acc=74.54% | lr=2.00e-04
# fold=4 | fixed CSV negatives | margin=0.50 | epoch=013/30 | train_loss=0.06447 | train_acc=97.92% | val_loss=0.15206 | val_mrr=0.2160 | val_acc=93.06% | val_margin_acc=72.69% | lr=2.00e-04
# Early stopping at epoch 13: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.50, fold=5/5 | train_rows=13837 | val_rows=235
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=001/30 | train_loss=0.24415 | train_acc=86.70% | val_loss=0.17128 | val_mrr=0.2204 | val_acc=89.79% | val_margin_acc=64.68% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=002/30 | train_loss=0.14430 | train_acc=93.89% | val_loss=0.18963 | val_mrr=0.2444 | val_acc=87.66% | val_margin_acc=65.96% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=003/30 | train_loss=0.12245 | train_acc=94.78% | val_loss=0.17805 | val_mrr=0.2159 | val_acc=90.21% | val_margin_acc=64.26% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=004/30 | train_loss=0.10948 | train_acc=95.77% | val_loss=0.18517 | val_mrr=0.2095 | val_acc=88.09% | val_margin_acc=63.83% | lr=2.00e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=005/30 | train_loss=0.10106 | train_acc=96.08% | val_loss=0.18201 | val_mrr=0.2219 | val_acc=87.66% | val_margin_acc=65.96% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=006/30 | train_loss=0.09110 | train_acc=96.44% | val_loss=0.20578 | val_mrr=0.2199 | val_acc=87.23% | val_margin_acc=62.13% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=007/30 | train_loss=0.08477 | train_acc=97.10% | val_loss=0.19114 | val_mrr=0.1971 | val_acc=88.51% | val_margin_acc=64.26% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=008/30 | train_loss=0.08077 | train_acc=97.07% | val_loss=0.20498 | val_mrr=0.1948 | val_acc=88.94% | val_margin_acc=62.98% | lr=1.40e-04
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=009/30 | train_loss=0.07769 | train_acc=97.20% | val_loss=0.19486 | val_mrr=0.2202 | val_acc=87.23% | val_margin_acc=61.70% | lr=9.80e-05
# fold=5 | fixed CSV negatives | margin=0.50 | epoch=010/30 | train_loss=0.07139 | train_acc=97.57% | val_loss=0.19896 | val_mrr=0.2067 | val_acc=88.51% | val_margin_acc=63.83% | lr=9.80e-05
# Early stopping at epoch 10: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.70, fold=1/5 | train_rows=14117 | val_rows=228
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=001/30 | train_loss=0.37550 | train_acc=85.88% | val_loss=0.31222 | val_mrr=0.2134 | val_acc=89.04% | val_margin_acc=50.00% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=002/30 | train_loss=0.24063 | train_acc=92.76% | val_loss=0.29533 | val_mrr=0.2034 | val_acc=88.60% | val_margin_acc=51.75% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=003/30 | train_loss=0.20800 | train_acc=93.96% | val_loss=0.28197 | val_mrr=0.2146 | val_acc=90.79% | val_margin_acc=53.07% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=004/30 | train_loss=0.19130 | train_acc=94.66% | val_loss=0.29832 | val_mrr=0.2340 | val_acc=88.16% | val_margin_acc=52.19% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=005/30 | train_loss=0.17722 | train_acc=95.27% | val_loss=0.29550 | val_mrr=0.2323 | val_acc=90.35% | val_margin_acc=51.32% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=006/30 | train_loss=0.16749 | train_acc=95.65% | val_loss=0.28623 | val_mrr=0.2271 | val_acc=89.04% | val_margin_acc=51.32% | lr=2.00e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=007/30 | train_loss=0.15751 | train_acc=96.04% | val_loss=0.29164 | val_mrr=0.2276 | val_acc=89.91% | val_margin_acc=50.88% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=008/30 | train_loss=0.14757 | train_acc=96.23% | val_loss=0.29047 | val_mrr=0.2287 | val_acc=89.91% | val_margin_acc=50.00% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=009/30 | train_loss=0.14110 | train_acc=96.57% | val_loss=0.28585 | val_mrr=0.2145 | val_acc=88.60% | val_margin_acc=52.19% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=010/30 | train_loss=0.13570 | train_acc=96.58% | val_loss=0.29680 | val_mrr=0.2462 | val_acc=88.60% | val_margin_acc=53.07% | lr=1.40e-04
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=011/30 | train_loss=0.13331 | train_acc=96.85% | val_loss=0.29321 | val_mrr=0.2400 | val_acc=89.04% | val_margin_acc=51.32% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=012/30 | train_loss=0.12427 | train_acc=97.18% | val_loss=0.29962 | val_mrr=0.2327 | val_acc=87.28% | val_margin_acc=52.19% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=013/30 | train_loss=0.12279 | train_acc=97.22% | val_loss=0.29971 | val_mrr=0.2179 | val_acc=88.16% | val_margin_acc=50.00% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=014/30 | train_loss=0.11895 | train_acc=97.14% | val_loss=0.30156 | val_mrr=0.2430 | val_acc=88.60% | val_margin_acc=52.19% | lr=9.80e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=015/30 | train_loss=0.11930 | train_acc=97.17% | val_loss=0.29263 | val_mrr=0.2264 | val_acc=90.35% | val_margin_acc=53.07% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=016/30 | train_loss=0.11338 | train_acc=97.35% | val_loss=0.29890 | val_mrr=0.2259 | val_acc=89.91% | val_margin_acc=50.44% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=017/30 | train_loss=0.11129 | train_acc=97.41% | val_loss=0.29466 | val_mrr=0.2338 | val_acc=89.47% | val_margin_acc=53.51% | lr=6.86e-05
# fold=1 | fixed CSV negatives | margin=0.70 | epoch=018/30 | train_loss=0.10908 | train_acc=97.65% | val_loss=0.28458 | val_mrr=0.2385 | val_acc=90.79% | val_margin_acc=53.95% | lr=6.86e-05
# Early stopping at epoch 18: no validation MRR improvement for 8 epochs.
# ====================================================================================================
# Training TripletNet3: fixed CSV negatives, margin=0.70, fold=2/5 | train_rows=13790 | val_rows=235
# fold=2 | fixed CSV negatives | margin=0.70 | epoch=001/30 | train_loss=0.37634 | train_acc=85.57% | val_loss=0.32961 | val_mrr=0.1564 | val_acc=85.11% | val_margin_acc=55.74% | lr=2.00e-04
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f1edb21ce30>>
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#       5         print("=" * 100)
#       6         print(
#       7             f"Training {MODEL_NAME}: fixed CSV negatives, "
#       8             f"margin={margin:.2f}, fold={fold_id}/{N_FOLDS} | "
#       9             f"train_rows={fold_stats['train_rows']} | val_rows={fold_stats['val_rows']}"
#      10         )
#      11         results.append(
# ---> 12             run_one_fold_margin(
#      13                 fold_id,
#      14                 train_df,
#      15                 val_df,
#      16                 margin,
#      17                 artist_averages,
#      18                 training_config,
#      19             )
#      20         )
#      22 fold_summary_df, margin_summary_df = summarize_cv_results(results, OUTPUT_DIR, MODEL_NAME)
#      24 display(fold_summary_df)
#
# File ~/autodl-tmp/thesis-artist-similarity/code/cv_training.py:339, in run_one_fold_margin(fold_id, train_df, val_df, margin, artist_averages, config)
#     336 history = []
#     338 for epoch in range(1, config.num_epochs + 1):
# --> 339     train_metrics = train(
#     340         model,
#     341         train_loader,
#     342         criterion,
#     343         optimizer,
#     344         config.device,
#     345         distance_fn=config.distance_fn,
#     346         grad_clip=config.grad_clip,
#     347         return_details=True,
#     348     )
#     349     val_metrics = evaluate(
#     350         model,
#     351         val_loader,
#    (...)    355         return_details=True,
#     356     )
#     357     val_mrr = _compute_validation_retrieval_mrr(model, val_df, artist_averages, config.device)
#
# File ~/autodl-tmp/thesis-artist-similarity/code/train.py:71, in train(model, train_loader, criterion, optimizer, device, distance_fn, grad_clip, return_details)
#      68 neg_dist_total = 0.0
#      69 margin = _criterion_margin(criterion)
# ---> 71 for batch in train_loader:
#      72     anchors, positives, negatives = _split_batch(batch)
#      73     anchors = anchors.to(device, non_blocking=True).float()
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:792, in _SingleProcessDataLoaderIter._next_data(self)
#     790 data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791 if self._pin_memory:
# --> 792     data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#     793 return data
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py:100, in pin_memory(data, device)
#      98     clone = copy.copy(data)  # type: ignore[arg-type]
#      99     for i, item in enumerate(data):
# --> 100         clone[i] = pin_memory(item, device)
#     101     return clone
#     102 return type(data)([pin_memory(sample, device) for sample in data])  # type: ignore[call-arg]
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py:66, in pin_memory(data, device)
#      64 def pin_memory(data, device=None):
#      65     if isinstance(data, torch.Tensor):
# ---> 66         return data.pin_memory(device)
#      67     elif isinstance(data, (str, bytes)):
#      68         return data
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post-training analysis plan
#
# After the 5-fold training finishes, this notebook reports the model from three complementary angles:
#
# 1. **Generalisation and stability**: compare margins across folds, inspect training/validation curves, and optionally compare all five model notebooks if their summary files exist.
# 2. **Triplet-learning quality**: aggregate out-of-fold validation predictions, then analyse positive vs negative cosine similarity, margin gaps, ranking accuracy, margin-satisfied accuracy, and threshold precision/recall/F1.
# 3. **Retrieval and latent-space usefulness**: use the selected best checkpoint to embed artists, compute nearest-neighbour retrieval metrics, inspect qualitative neighbours/errors, and visualise/diagnose the latent space using metadata when available.
#
# The out-of-fold triplet analysis is the primary quantitative evidence because every prediction is made by a model that did not train on that fold's anchor artists. The latent-space plots and nearest-neighbour examples are interpretability checks, not the sole performance evidence.

# %%
import math
import warnings
from collections import defaultdict

import torch.nn.functional as F

ANALYSIS_DIR = OUTPUT_DIR / "analysis"
ANALYSIS_DIR.mkdir(parents=True, exist_ok=True)

fold_summary_path = OUTPUT_DIR / f"{MODEL_NAME}_5fold_fold_summary.csv"
margin_summary_path = OUTPUT_DIR / f"{MODEL_NAME}_5fold_margin_summary.csv"
if "margin_summary_df" not in globals() and "results" in globals() and "summarize_cv_results" in globals():
    fold_summary_df, margin_summary_df = summarize_cv_results(results, OUTPUT_DIR, MODEL_NAME)
if "margin_summary_df" not in globals() and margin_summary_path.exists():
    margin_summary_df = pd.read_csv(margin_summary_path)
    print(f"Loaded cached margin summary: {margin_summary_path}")
if "fold_summary_df" not in globals() and fold_summary_path.exists():
    fold_summary_df = pd.read_csv(fold_summary_path)
    print(f"Loaded cached fold summary: {fold_summary_path}")
missing_training_state = [name for name in ["margin_summary_df", "results"] if name not in globals()]
if missing_training_state:
    raise RuntimeError(
        "Missing training state: " + ", ".join(missing_training_state) + ". "
        "Run the cross-validation/training cell that creates `results`, or restore the corresponding checkpoints directory. "
        "Saved notebook outputs do not recreate Python variables after a kernel restart."
    )

# Select the best margin by mean 5-fold validation MRR. Ties prefer higher ranking accuracy, then lower loss.
best_margin = float(margin_summary_df.iloc[0]["margin"])
best_margin_results = sorted(
    [item for item in results if float(item["margin"]) == best_margin],
    key=lambda item: int(item["fold"]),
)
best_fold_result = max(
    best_margin_results,
    key=lambda item: (item["best_val_mrr"], item["best_val_acc"], -item["best_val_loss"]),
)


def load_model_from_checkpoint(checkpoint_path: str | Path):
    checkpoint_path = Path(checkpoint_path)
    model = make_model()
    state = torch.load(checkpoint_path, map_location=DEVICE)
    model.load_state_dict(state)
    model.eval()
    return model


def encode_triplet_distances(model, triplets, fold: int | None = None, margin: float | None = None) -> pd.DataFrame:
    rows = []
    model.eval()
    margin = best_margin if margin is None else float(margin)
    with torch.inference_mode():
        for idx, (anchor, positive, negative) in enumerate(triplets):
            anchor_input = anchor.unsqueeze(0).to(DEVICE).float()
            positive_input = positive.unsqueeze(0).to(DEVICE).float()
            negative_input = negative.unsqueeze(0).to(DEVICE).float()

            anchor_emb, positive_emb, negative_emb = model(anchor_input, positive_input, negative_input)
            positive_similarity = F.cosine_similarity(anchor_emb, positive_emb, dim=1).item()
            negative_similarity = F.cosine_similarity(anchor_emb, negative_emb, dim=1).item()
            positive_distance = 1.0 - positive_similarity
            negative_distance = 1.0 - negative_similarity
            margin_gap = negative_distance - positive_distance

            rows.append({
                "fold": fold,
                "triplet_id": idx,
                "positive_similarity": positive_similarity,
                "negative_similarity": negative_similarity,
                "positive_distance": positive_distance,
                "negative_distance": negative_distance,
                "similarity_gap": positive_similarity - negative_similarity,
                "margin_gap": margin_gap,
                "ranking_correct": positive_distance < negative_distance,
                "margin_satisfied": positive_distance + margin < negative_distance,
            })
    return pd.DataFrame(rows)


def build_oof_triplet_predictions() -> pd.DataFrame:
    frames = []
    for item in best_margin_results:
        fold_model = load_model_from_checkpoint(item["checkpoint_path"])
        fold_df = encode_triplet_distances(
            fold_model,
            item["val_triplets"],
            fold=int(item["fold"]),
            margin=float(item["margin"]),
        )
        fold_df["model"] = item["model"]
        fold_df["margin"] = float(item["margin"])
        fold_df["checkpoint_path"] = item["checkpoint_path"]
        frames.append(fold_df)
    if not frames:
        raise RuntimeError("No validation predictions were generated. Check results/best_margin_results.")
    return pd.concat(frames, ignore_index=True)


def pair_threshold_curve(oof_df: pd.DataFrame, thresholds: np.ndarray | None = None) -> pd.DataFrame:
    if thresholds is None:
        min_score = float(min(oof_df["positive_similarity"].min(), oof_df["negative_similarity"].min()))
        max_score = float(max(oof_df["positive_similarity"].max(), oof_df["negative_similarity"].max()))
        lower = max(-1.0, math.floor(min_score * 100) / 100)
        upper = min(1.0, math.ceil(max_score * 100) / 100)
        thresholds = np.linspace(lower, upper, 101)

    pos_scores = oof_df["positive_similarity"].to_numpy(dtype=float)
    neg_scores = oof_df["negative_similarity"].to_numpy(dtype=float)
    rows = []
    for threshold in thresholds:
        tp = int((pos_scores >= threshold).sum())
        fn = int((pos_scores < threshold).sum())
        fp = int((neg_scores >= threshold).sum())
        tn = int((neg_scores < threshold).sum())
        precision = tp / (tp + fp) if (tp + fp) else 0.0
        recall = tp / (tp + fn) if (tp + fn) else 0.0
        specificity = tn / (tn + fp) if (tn + fp) else 0.0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0.0
        rows.append({
            "threshold": float(threshold),
            "precision": precision,
            "recall": recall,
            "specificity": specificity,
            "f1": f1,
            "tp": tp,
            "fp": fp,
            "fn": fn,
            "tn": tn,
        })
    return pd.DataFrame(rows)


def safe_auc_metrics(oof_df: pd.DataFrame) -> dict[str, float]:
    y_true = np.concatenate([
        np.ones(len(oof_df), dtype=int),
        np.zeros(len(oof_df), dtype=int),
    ])
    y_score = np.concatenate([
        oof_df["positive_similarity"].to_numpy(dtype=float),
        oof_df["negative_similarity"].to_numpy(dtype=float),
    ])
    out = {"roc_auc": float("nan"), "average_precision": float("nan")}
    try:
        from sklearn.metrics import average_precision_score, roc_auc_score
        out["roc_auc"] = float(roc_auc_score(y_true, y_score))
        out["average_precision"] = float(average_precision_score(y_true, y_score))
    except Exception as exc:
        warnings.warn(f"sklearn metrics unavailable; ROC-AUC/AP skipped: {exc}")
    return out


oof_triplet_df = build_oof_triplet_predictions()
threshold_metrics_df = pair_threshold_curve(oof_triplet_df)
best_threshold_row = threshold_metrics_df.sort_values(["f1", "precision", "recall"], ascending=False).iloc[0]
auc_metrics = safe_auc_metrics(oof_triplet_df)

best_model = load_model_from_checkpoint(best_fold_result["checkpoint_path"])
best_checkpoint_path = Path(best_fold_result["checkpoint_path"])

print(f"Best margin by 5-fold mean validation MRR: {best_margin:.2f}")
print(f"Best single fold checkpoint for embedding-level analysis: fold={best_fold_result['fold']} -> {best_checkpoint_path}")
print(f"Out-of-fold validation triplets: {len(oof_triplet_df)}")
print(f"OOF ranking accuracy: {oof_triplet_df['ranking_correct'].mean():.2%}")
print(f"OOF margin-satisfied accuracy: {oof_triplet_df['margin_satisfied'].mean():.2%}")
print(f"Best threshold by F1: {best_threshold_row['threshold']:.3f}")
print(f"ROC-AUC: {auc_metrics['roc_auc']:.4f} | Average precision: {auc_metrics['average_precision']:.4f}")

display(oof_triplet_df.describe())
display(threshold_metrics_df.sort_values("f1", ascending=False).head(10))

# %% [markdown]
# ### 1. Cross-validation stability and cross-model comparison

# %%
# 1) Cross-validation stability: margin ranking and training curves.
cv_display = margin_summary_df.copy()
for col in [
    "mean_best_val_mrr",
    "std_best_val_mrr",
    "mean_best_val_acc",
    "std_best_val_acc",
    "mean_best_val_margin_acc",
    "std_best_val_margin_acc",
]:
    if col in cv_display.columns:
        cv_display[col] = cv_display[col].astype(float)

display(cv_display)

fig, ax = plt.subplots(figsize=(9, 5))
ax.errorbar(
    cv_display["margin"].astype(float),
    cv_display["mean_best_val_mrr"].astype(float),
    yerr=cv_display["std_best_val_mrr"].fillna(0).astype(float),
    marker="^",
    capsize=4,
    label="validation MRR",
)
ax.errorbar(
    cv_display["margin"].astype(float),
    cv_display["mean_best_val_acc"].astype(float),
    yerr=cv_display["std_best_val_acc"].fillna(0).astype(float),
    marker="o",
    capsize=4,
    label="ranking accuracy",
)
ax.errorbar(
    cv_display["margin"].astype(float),
    cv_display["mean_best_val_margin_acc"].astype(float),
    yerr=cv_display["std_best_val_margin_acc"].fillna(0).astype(float),
    marker="s",
    capsize=4,
    label="margin-satisfied accuracy",
)
ax.set_xlabel("Triplet margin")
ax.set_ylabel("5-fold mean validation score")
ax.set_title(f"{MODEL_NAME}: margin sensitivity across 5 folds (best by MRR)")
ax.grid(True, alpha=0.3)
ax.legend()
save_figure(fig, "margin_sensitivity.png")
plt.show()


def plot_cv_history_for_margin(results: list[dict], margin: float):
    histories = [item["history"] for item in results if float(item["margin"]) == float(margin)]
    if not histories:
        raise ValueError(f"No histories found for margin={margin}")
    combined = pd.concat(histories, ignore_index=True)
    agg_spec = {
        "train_loss": ("train_loss", "mean"),
        "val_loss": ("val_loss", "mean"),
        "val_mrr": ("val_mrr", "mean"),
        "train_acc": ("train_acc", "mean"),
        "val_acc": ("val_acc", "mean"),
        "val_margin_acc": ("val_margin_acc", "mean"),
    }
    for metric in ["mean_pos_dist", "mean_neg_dist"]:
        if metric in combined.columns:
            agg_spec[metric] = (metric, "mean")
    cv_history = combined.groupby("epoch", as_index=False).agg(**agg_spec)

    fig, ax1 = plt.subplots(figsize=(9, 5))
    ax1.plot(cv_history["epoch"], cv_history["train_loss"], label="train loss")
    ax1.plot(cv_history["epoch"], cv_history["val_loss"], label="validation loss")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.grid(True, alpha=0.3)

    ax2 = ax1.twinx()
    ax2.plot(cv_history["epoch"], cv_history["train_acc"], linestyle="--", label="train ranking acc")
    ax2.plot(cv_history["epoch"], cv_history["val_acc"], linestyle="--", label="validation ranking acc")
    ax2.plot(cv_history["epoch"], cv_history["val_mrr"], linestyle=":", label="validation MRR")
    ax2.plot(cv_history["epoch"], cv_history["val_margin_acc"], linestyle=":", label="validation margin acc")
    ax2.set_ylabel("Accuracy")

    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc="center right")
    ax1.set_title(f"{MODEL_NAME}: mean 5-fold history, margin={margin:.2f}")
    save_figure(fig, f"cv_history_margin_{margin:.2f}.png")
    plt.show()


    return cv_history

cv_history_df = plot_cv_history_for_margin(results, best_margin)
display(cv_history_df.tail())

# Optional cross-notebook comparison. This becomes useful after running model1.ipynb ... model4.ipynb.
def load_available_model_summaries(root: Path = Path("checkpoints")) -> pd.DataFrame:
    frames = []
    for path in sorted(root.glob("TripletNet*/TripletNet*_5fold_margin_summary.csv")):
        try:
            df = pd.read_csv(path)
            df["summary_path"] = str(path)
            frames.append(df)
        except Exception as exc:
            print(f"Skipping {path}: {exc}")
    if not frames:
        return pd.DataFrame()
    return pd.concat(frames, ignore_index=True)

all_model_summaries = load_available_model_summaries()
if not all_model_summaries.empty and "mean_best_val_mrr" not in all_model_summaries.columns:
    print("Existing summaries do not contain validation MRR yet. Re-run all model notebooks after this update.")
    all_model_summaries = pd.DataFrame()
if not all_model_summaries.empty:
    if "margin" in all_model_summaries.columns:
        all_model_summaries = all_model_summaries.loc[
            all_model_summaries["margin"].astype(float).isin(MARGINS)
        ].copy()
if all_model_summaries.empty:
    print(
        f"No cross-model summaries found for fixed CSV negatives and margins={MARGINS}. "
        "Run the other model notebooks to enable model-level comparison."
    )
else:
    best_per_model = (
        all_model_summaries.sort_values(["model", "mean_best_val_mrr", "mean_best_val_acc", "mean_best_val_loss"], ascending=[True, False, False, True])
        .groupby("model", as_index=False)
        .head(1)
        .sort_values("mean_best_val_mrr", ascending=False)
        .reset_index(drop=True)
    )
    display_cols = [
        col for col in [
            "model",
            "margin",
            "mean_best_val_mrr",
            "std_best_val_mrr",
            "mean_best_val_acc",
            "std_best_val_acc",
            "mean_best_val_loss",
            "mean_best_val_margin_acc",
                                ]
        if col in best_per_model.columns
    ]
    display(best_per_model[display_cols])

    fig, ax = plt.subplots(figsize=(9, 5))
    ax.bar(best_per_model["model"], best_per_model["mean_best_val_mrr"])
    ax.set_ylabel("Best mean 5-fold validation MRR")
    ax.set_title("Best validation MRR per model")
    ax.grid(axis="y", alpha=0.3)
    plt.xticks(rotation=30, ha="right")
    save_figure(fig, "cross_model_best_validation_mrr.png")
    plt.show()

# %% [markdown]
# ### 2. Out-of-fold triplet quality and threshold analysis

# %%
# 2) Triplet-level out-of-fold analysis: distances, gaps, threshold precision/recall.
triplet_summary = pd.DataFrame([{
    "model": MODEL_NAME,
    "best_margin": best_margin,
    "selection_metric": "validation_mrr",
    "best_fold": best_fold_result["fold"],
    "best_fold_val_mrr": best_fold_result["best_val_mrr"],
    "best_fold_val_acc": best_fold_result["best_val_acc"],
    "oof_triplets": len(oof_triplet_df),
    "ranking_accuracy": oof_triplet_df["ranking_correct"].mean(),
    "margin_satisfied_accuracy": oof_triplet_df["margin_satisfied"].mean(),
    "mean_positive_similarity": oof_triplet_df["positive_similarity"].mean(),
    "mean_negative_similarity": oof_triplet_df["negative_similarity"].mean(),
    "mean_similarity_gap": oof_triplet_df["similarity_gap"].mean(),
    "mean_positive_distance": oof_triplet_df["positive_distance"].mean(),
    "mean_negative_distance": oof_triplet_df["negative_distance"].mean(),
    "mean_margin_gap": oof_triplet_df["margin_gap"].mean(),
    "roc_auc": auc_metrics["roc_auc"],
    "average_precision": auc_metrics["average_precision"],
    "best_f1_threshold": best_threshold_row["threshold"],
    "best_threshold_precision": best_threshold_row["precision"],
    "best_threshold_recall": best_threshold_row["recall"],
    "best_threshold_f1": best_threshold_row["f1"],
}])
display(triplet_summary)

fig, ax = plt.subplots(figsize=(9, 5))
ax.hist(oof_triplet_df["positive_similarity"], bins=50, alpha=0.65, label="anchor-positive")
ax.hist(oof_triplet_df["negative_similarity"], bins=50, alpha=0.65, label="anchor-negative")
ax.axvline(float(best_threshold_row["threshold"]), linestyle="--", label="best F1 threshold")
ax.set_xlabel("Cosine similarity")
ax.set_ylabel("Count")
ax.set_title(f"{MODEL_NAME}: out-of-fold positive vs negative similarity")
ax.grid(True, alpha=0.3)
ax.legend()
save_figure(fig, "oof_positive_negative_similarity.png")
plt.show()

fig, ax = plt.subplots(figsize=(9, 5))
ax.hist(oof_triplet_df["margin_gap"], bins=50, alpha=0.75)
ax.axvline(0.0, linestyle="--", label="ranking boundary")
ax.axvline(best_margin, linestyle=":", label="margin-satisfied boundary")
ax.set_xlabel("negative_distance - positive_distance")
ax.set_ylabel("Count")
ax.set_title(f"{MODEL_NAME}: margin gap distribution")
ax.grid(True, alpha=0.3)
ax.legend()
save_figure(fig, "oof_margin_gap_distribution.png")
plt.show()

fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(threshold_metrics_df["threshold"], threshold_metrics_df["precision"], label="precision")
ax.plot(threshold_metrics_df["threshold"], threshold_metrics_df["recall"], label="recall")
ax.plot(threshold_metrics_df["threshold"], threshold_metrics_df["f1"], label="F1")
ax.axvline(float(best_threshold_row["threshold"]), linestyle="--", label="best F1 threshold")
ax.set_xlabel("Cosine similarity threshold")
ax.set_ylabel("Score")
ax.set_title(f"{MODEL_NAME}: pair-level threshold analysis")
ax.grid(True, alpha=0.3)
ax.legend()
save_figure(fig, "pair_threshold_analysis.png")
plt.show()

hardest_triplets = oof_triplet_df.sort_values("similarity_gap").head(20).reset_index(drop=True)
display(hardest_triplets[[
    "fold", "triplet_id", "positive_similarity", "negative_similarity", "similarity_gap",
    "positive_distance", "negative_distance", "margin_gap", "ranking_correct", "margin_satisfied"
]])

# %% [markdown]
# ### 3. Retrieval metrics and qualitative nearest neighbours

# %%
# 3) Retrieval analysis: nearest-neighbour quality in the learned artist latent space.
@torch.inference_mode()
def encode_artists(model, artist_tensors: dict[str, torch.Tensor], batch_size: int = 256) -> pd.DataFrame:
    model.eval()
    artist_ids = sorted(map(str, artist_tensors.keys()))
    embedding_chunks = []
    for start in range(0, len(artist_ids), batch_size):
        batch_ids = artist_ids[start:start + batch_size]
        batch = torch.stack([artist_tensors[artist_id].float() for artist_id in batch_ids], dim=0).to(DEVICE)
        encoded = model.forward_once(batch).detach().cpu().float()
        encoded = F.normalize(encoded, dim=1, eps=1e-8)
        embedding_chunks.append(encoded.numpy())
    matrix = np.vstack(embedding_chunks)
    columns = [f"z_{i:03d}" for i in range(matrix.shape[1])]
    return pd.DataFrame(matrix, index=artist_ids, columns=columns)


def build_ground_truth_positive_sets(df: pd.DataFrame, available_ids: set[str], symmetric: bool = True) -> dict[str, set[str]]:
    positives = defaultdict(set)
    clean = df.copy()
    for col in TRIPLET_COLUMNS:
        clean[col] = clean[col].astype(str)
    for row in clean.itertuples(index=False):
        anchor = str(getattr(row, "anchor"))
        positive = str(getattr(row, "positive"))
        if anchor in available_ids and positive in available_ids and anchor != positive:
            positives[anchor].add(positive)
            if symmetric:
                positives[positive].add(anchor)
    return dict(positives)


def compute_retrieval_metrics(embedding_df: pd.DataFrame, positive_sets: dict[str, set[str]], ks=(1, 5, 10, 20)):
    artist_ids = embedding_df.index.astype(str).tolist()
    id_to_idx = {artist_id: idx for idx, artist_id in enumerate(artist_ids)}
    matrix = embedding_df.to_numpy(dtype=np.float32)
    matrix = matrix / np.maximum(np.linalg.norm(matrix, axis=1, keepdims=True), 1e-8)
    similarity = matrix @ matrix.T
    np.fill_diagonal(similarity, -np.inf)

    rows = []
    nearest_rows = []
    for anchor_id, positives in positive_sets.items():
        if anchor_id not in id_to_idx:
            continue
        positives = {p for p in positives if p in id_to_idx and p != anchor_id}
        if not positives:
            continue
        anchor_idx = id_to_idx[anchor_id]
        order = np.argsort(-similarity[anchor_idx])
        ranked_ids = [artist_ids[i] for i in order]
        ranked_positive_flags = np.array([candidate in positives for candidate in ranked_ids], dtype=bool)

        row = {
            "anchor": anchor_id,
            "num_positives": len(positives),
        }
        for k in ks:
            topk_flags = ranked_positive_flags[:k]
            hits = int(topk_flags.sum())
            row[f"precision@{k}"] = hits / k
            row[f"recall@{k}"] = hits / len(positives)
            row[f"hit@{k}"] = float(hits > 0)

        positive_ranks = np.flatnonzero(ranked_positive_flags) + 1
        row["mrr"] = 1.0 / positive_ranks[0] if len(positive_ranks) else 0.0
        if len(positive_ranks):
            precisions_at_hits = []
            for rank in positive_ranks:
                precisions_at_hits.append(ranked_positive_flags[:rank].sum() / rank)
            row["average_precision"] = float(np.sum(precisions_at_hits) / len(positives))
        else:
            row["average_precision"] = 0.0
        rows.append(row)

        for rank, candidate_idx in enumerate(order[:10], start=1):
            candidate_id = artist_ids[candidate_idx]
            nearest_rows.append({
                "anchor": anchor_id,
                "rank": rank,
                "candidate": candidate_id,
                "cosine_similarity": float(similarity[anchor_idx, candidate_idx]),
                "is_ground_truth_positive": candidate_id in positives,
            })

    metric_df = pd.DataFrame(rows)
    nearest_df = pd.DataFrame(nearest_rows)
    if metric_df.empty:
        summary = pd.DataFrame()
    else:
        summary = metric_df.drop(columns=["anchor"]).mean(numeric_only=True).to_frame("mean").T
        summary.insert(0, "model", MODEL_NAME)
        summary.insert(1, "checkpoint", str(best_checkpoint_path))
    return metric_df, summary, nearest_df

artist_embedding_df = encode_artists(best_model, artist_averages)
positive_sets = build_ground_truth_positive_sets(filtered_triplet_df, set(artist_embedding_df.index), symmetric=True)
retrieval_metric_df, retrieval_summary_df, nearest_neighbors_df = compute_retrieval_metrics(
    artist_embedding_df,
    positive_sets,
    ks=(1, 5, 10, 20),
)

print(f"Encoded artists: {len(artist_embedding_df)}")
print(f"Artists with at least one ground-truth positive: {len(positive_sets)}")
display(retrieval_summary_df)
display(retrieval_metric_df.sort_values("average_precision", ascending=False).head(10))
display(retrieval_metric_df.sort_values("average_precision", ascending=True).head(10))
display(nearest_neighbors_df.head(50))

# %% [markdown]
# ### 4. Latent-space visualisation and metadata consistency

# %%
# 4) Metadata-aware latent-space analysis: t-SNE/PCA and group similarity.
def load_artist_metadata() -> pd.DataFrame:
    metadata_dirs = [Path("../data/metadata"), Path("data/metadata"), Path(".")]
    metadata_filenames = [
        "artists_genre_country.csv",
        "artists_genre_country_major_genres.csv",
        "artists.csv",
        "artists_metadata.csv",
        "metadata.csv",
    ]
    candidate_paths = [metadata_dir / filename for metadata_dir in metadata_dirs for filename in metadata_filenames]
    for path in candidate_paths:
        if not path.exists():
            continue
        df = pd.read_csv(path)
        df.columns = [str(col).strip() for col in df.columns]
        lower_map = {col.lower(): col for col in df.columns}
        id_col = None
        for candidate in ["musicbrainz_id", "artist_id", "id", "mbid"]:
            if candidate in lower_map:
                id_col = lower_map[candidate]
                break
        if id_col is None:
            print(f"Skipping metadata file without artist id column: {path}")
            continue
        df = df.rename(columns={id_col: "artist_id"})
        df["artist_id"] = df["artist_id"].astype(str)
        df["metadata_source"] = str(path)
        return df
    return pd.DataFrame()


def infer_column(df: pd.DataFrame, candidates: list[str]) -> str | None:
    lower_map = {col.lower(): col for col in df.columns}
    for candidate in candidates:
        if candidate.lower() in lower_map:
            return lower_map[candidate.lower()]
    return None

artist_metadata_df = load_artist_metadata()
if artist_metadata_df.empty:
    print("No metadata file found. t-SNE and intra/inter-group similarity by country/genre are skipped.")
else:
    country_col = infer_column(artist_metadata_df, ["country", "nationality", "artist_country"])
    genre_col = infer_column(artist_metadata_df, ["genre", "genres", "general_genre", "main_genre", "music_genre"])
    name_col = infer_column(artist_metadata_df, ["name", "artist", "artist_name"])

    metadata_embedding_df = artist_embedding_df.reset_index(names="artist_id").merge(artist_metadata_df, on="artist_id", how="left")
    display(metadata_embedding_df.head())

    projection_cache: dict[tuple[str, int], pd.DataFrame] = {}

    def build_shared_projection(method: str = "tsne", max_points: int = 2500) -> pd.DataFrame | None:
        method = method.lower()
        cache_key = (method, max_points)
        if cache_key in projection_cache:
            return projection_cache[cache_key].copy()

        feature_cols = [col for col in metadata_embedding_df.columns if col.startswith("z_")]
        if not feature_cols:
            print("No latent embedding columns found for projection.")
            return None

        projection_df = metadata_embedding_df.dropna(subset=feature_cols).copy()
        if len(projection_df) > max_points:
            projection_df = projection_df.sample(max_points, random_state=SEED).copy()
        if len(projection_df) < 2:
            print(f"{method.upper()} skipped: at least two artists are required.")
            return None

        x = projection_df[feature_cols].to_numpy(dtype=np.float32)
        try:
            from sklearn.decomposition import PCA
            if method == "pca":
                coords = PCA(n_components=2, random_state=SEED).fit_transform(x)
            elif method == "tsne":
                from sklearn.manifold import TSNE
                pca_components = min(50, x.shape[1], len(projection_df) - 1)
                x_for_tsne = x
                if pca_components >= 2 and pca_components < x.shape[1]:
                    x_for_tsne = PCA(n_components=pca_components, random_state=SEED).fit_transform(x)
                x_for_tsne = x_for_tsne / np.maximum(np.linalg.norm(x_for_tsne, axis=1, keepdims=True), 1e-8)
                perplexity = min(40, max(5, (len(projection_df) - 1) // 3))
                perplexity = min(perplexity, max(1, len(projection_df) - 1))
                kwargs = dict(n_components=2, random_state=SEED, metric="cosine", init="pca", perplexity=perplexity)
                try:
                    coords = TSNE(max_iter=1000, **kwargs).fit_transform(x_for_tsne)
                except TypeError:
                    coords = TSNE(n_iter=1000, **kwargs).fit_transform(x_for_tsne)
            else:
                raise ValueError(f"Unsupported projection method: {method}")
        except Exception as exc:
            print(f"{method.upper()} skipped: {exc}")
            return None

        projection_df["dim_1"] = coords[:, 0]
        projection_df["dim_2"] = coords[:, 1]
        projection_cache[cache_key] = projection_df.copy()
        return projection_df

    def plot_latent_projection(label_col: str | None, method: str = "tsne", max_points: int = 2500):
        if label_col is None or label_col not in metadata_embedding_df.columns:
            print(f"No usable label column for {method.upper()} plot.")
            return None
        plot_df = build_shared_projection(method=method, max_points=max_points)
        if plot_df is None or plot_df.empty:
            return None

        labels = plot_df[label_col].fillna("Unknown").astype(str)
        top_labels = labels.value_counts().head(12).index.tolist()
        plot_df["plot_label"] = np.where(labels.isin(top_labels), labels, "Other")

        fig, ax = plt.subplots(figsize=(10, 7))
        for label, group in plot_df.groupby("plot_label"):
            ax.scatter(group["dim_1"], group["dim_2"], s=12, alpha=0.75, label=label)
        ax.set_title(f"{MODEL_NAME}: {method.upper()} latent space by {label_col}")
        ax.set_xlabel("Dimension 1")
        ax.set_ylabel("Dimension 2")
        ax.grid(True, alpha=0.2)
        ax.legend(markerscale=2, fontsize=8, bbox_to_anchor=(1.02, 1), loc="upper left")
        plt.tight_layout()
        save_figure(fig, f"{method}_{label_col}_latent_space.png")
        plt.show()
        return plot_df

    pca_country_df = plot_latent_projection(country_col, method="pca")
    tsne_country_df = plot_latent_projection(country_col, method="tsne")
    if genre_col is not None and genre_col != country_col:
        pca_genre_df = plot_latent_projection(genre_col, method="pca")
        tsne_genre_df = plot_latent_projection(genre_col, method="tsne")

    def group_similarity_summary(label_col: str | None, min_group_size: int = 5, max_pairs: int = 20000) -> pd.DataFrame:
        if label_col is None or label_col not in metadata_embedding_df.columns:
            return pd.DataFrame()
        df = metadata_embedding_df.dropna(subset=[label_col]).copy()
        feature_cols = [col for col in df.columns if col.startswith("z_")]
        matrix = df[feature_cols].to_numpy(dtype=np.float32)
        matrix = matrix / np.maximum(np.linalg.norm(matrix, axis=1, keepdims=True), 1e-8)
        labels = df[label_col].astype(str).to_numpy()
        rng = np.random.default_rng(SEED)
        rows = []
        for label in sorted(pd.Series(labels).dropna().unique()):
            idx = np.flatnonzero(labels == label)
            other_idx = np.flatnonzero(labels != label)
            if len(idx) < min_group_size or len(other_idx) == 0:
                continue

            n_possible = len(idx) * (len(idx) - 1) // 2
            n_pairs = min(max_pairs, n_possible)
            if n_pairs <= 0:
                continue
            i = rng.choice(idx, size=n_pairs, replace=True)
            j = rng.choice(idx, size=n_pairs, replace=True)
            keep = i != j
            i, j = i[keep], j[keep]
            if len(i) == 0:
                continue
            intra = np.sum(matrix[i] * matrix[j], axis=1)

            inter_i = rng.choice(idx, size=len(i), replace=True)
            inter_j = rng.choice(other_idx, size=len(i), replace=True)
            inter = np.sum(matrix[inter_i] * matrix[inter_j], axis=1)

            rows.append({
                "label_column": label_col,
                "label": label,
                "n_artists": len(idx),
                "mean_intra_similarity": float(np.mean(intra)),
                "std_intra_similarity": float(np.std(intra)),
                "mean_inter_similarity": float(np.mean(inter)),
                "std_inter_similarity": float(np.std(inter)),
                "intra_minus_inter": float(np.mean(intra) - np.mean(inter)),
            })
        return pd.DataFrame(rows).sort_values("intra_minus_inter", ascending=False).reset_index(drop=True)

    country_similarity_df = group_similarity_summary(country_col)
    genre_similarity_df = group_similarity_summary(genre_col)
    if not country_similarity_df.empty:
        display(country_similarity_df)
    if not genre_similarity_df.empty:
        display(genre_similarity_df)

# %% [markdown]
# ### 5. Error analysis and exported result files

# %%
# 5) Error analysis and artifact export.
threshold = float(best_threshold_row["threshold"])
positive_pair_df = oof_triplet_df[["fold", "triplet_id", "positive_similarity"]].rename(
    columns={"positive_similarity": "similarity"}
)
positive_pair_df["pair_label"] = 1
positive_pair_df["predicted_positive"] = positive_pair_df["similarity"] >= threshold

negative_pair_df = oof_triplet_df[["fold", "triplet_id", "negative_similarity"]].rename(
    columns={"negative_similarity": "similarity"}
)
negative_pair_df["pair_label"] = 0
negative_pair_df["predicted_positive"] = negative_pair_df["similarity"] >= threshold

pair_error_df = pd.concat([positive_pair_df, negative_pair_df], ignore_index=True)
pair_error_df["error_type"] = np.select(
    [
        (pair_error_df["pair_label"] == 1) & (~pair_error_df["predicted_positive"]),
        (pair_error_df["pair_label"] == 0) & (pair_error_df["predicted_positive"]),
    ],
    ["false_negative_positive_pair", "false_positive_negative_pair"],
    default="correct",
)

false_positive_pairs = pair_error_df[pair_error_df["error_type"] == "false_positive_negative_pair"].sort_values("similarity", ascending=False)
false_negative_pairs = pair_error_df[pair_error_df["error_type"] == "false_negative_positive_pair"].sort_values("similarity", ascending=True)

print(f"Threshold used for pair error analysis: {threshold:.3f}")
print(f"False-positive negative pairs: {len(false_positive_pairs)}")
print(f"False-negative positive pairs: {len(false_negative_pairs)}")
display(false_positive_pairs.head(20))
display(false_negative_pairs.head(20))

# Save everything needed for the thesis/results section.
oof_triplet_path = ANALYSIS_DIR / f"{MODEL_NAME}_oof_triplet_predictions.csv"
threshold_path = ANALYSIS_DIR / f"{MODEL_NAME}_threshold_metrics.csv"
triplet_summary_path = ANALYSIS_DIR / f"{MODEL_NAME}_triplet_summary.csv"
retrieval_metric_path = ANALYSIS_DIR / f"{MODEL_NAME}_retrieval_per_anchor.csv"
retrieval_summary_path = ANALYSIS_DIR / f"{MODEL_NAME}_retrieval_summary.csv"
nearest_neighbors_path = ANALYSIS_DIR / f"{MODEL_NAME}_nearest_neighbors.csv"
pair_error_path = ANALYSIS_DIR / f"{MODEL_NAME}_pair_error_analysis.csv"
artist_embedding_path = ANALYSIS_DIR / f"{MODEL_NAME}_artist_latent_embeddings.csv"

oof_triplet_df.to_csv(oof_triplet_path, index=False)
threshold_metrics_df.to_csv(threshold_path, index=False)
triplet_summary.to_csv(triplet_summary_path, index=False)
retrieval_metric_df.to_csv(retrieval_metric_path, index=False)
retrieval_summary_df.to_csv(retrieval_summary_path, index=False)
nearest_neighbors_df.to_csv(nearest_neighbors_path, index=False)
pair_error_df.to_csv(pair_error_path, index=False)
artist_embedding_df.reset_index(names="artist_id").to_csv(artist_embedding_path, index=False)

if "country_similarity_df" in globals() and isinstance(country_similarity_df, pd.DataFrame) and not country_similarity_df.empty:
    country_similarity_df.to_csv(ANALYSIS_DIR / f"{MODEL_NAME}_country_similarity_summary.csv", index=False)
if "genre_similarity_df" in globals() and isinstance(genre_similarity_df, pd.DataFrame) and not genre_similarity_df.empty:
    genre_similarity_df.to_csv(ANALYSIS_DIR / f"{MODEL_NAME}_genre_similarity_summary.csv", index=False)

print("Saved analysis artifacts to:")
for path in [
    oof_triplet_path,
    threshold_path,
    triplet_summary_path,
    retrieval_metric_path,
    retrieval_summary_path,
    nearest_neighbors_path,
    pair_error_path,
    artist_embedding_path,
]:
    print(" -", path)
